# %%
import  pandas as pd

# %%
aa_ci = pd.read_csv('Austin_Animal_Center_Intakes.csv')
aa_ci
# Out:
#        Animal ID       Name                DateTime     MonthYear  \
# 0        A665644        NaN  10/21/2013 07:59:00 AM  October 2013
# 1        A665739     *Alana  10/22/2013 11:11:00 AM  October 2013
# 2        A665763        NaN  10/22/2013 03:10:00 PM  October 2013
# 3        A379998   Disciple  10/23/2013 11:42:00 AM  October 2013
# 4        A634503      Otter  10/01/2013 02:49:00 PM  October 2013
# ...          ...        ...                     ...           ...
# 155810   A886667        NaN  08/09/2023 09:49:00 AM   August 2023
# 155811   A883852     *Percy  06/24/2023 03:00:00 PM     June 2023
# 155812   A886631  *Franklin  08/08/2023 02:56:00 PM   August 2023
# 155813   A882170        Osa  08/09/2023 12:02:00 PM   August 2023
# 155814   A886632     *Teddy  08/08/2023 02:56:00 PM   August 2023
#
#                                            Found Location      Intake Type  \
# 0                                             Austin (TX)            Stray
# ...

# %%
aa_co = pd.read_csv('Austin_Animal_Center_Outcomes.csv')
aa_co
# Out:
#        Animal ID       Name                DateTime MonthYear Date of Birth  \
# 0        A794011      Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 1        A776359      Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 2        A821648        NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 3        A720371      Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
# 4        A674754        NaN  03/18/2014 11:47:00 AM  Mar 2014    03/12/2014
# ...          ...        ...                     ...       ...           ...
# 155779   A889182    *Olivia  09/29/2023 12:21:00 PM  Sep 2023    03/18/2021
# 155780   A864538    Delilah  09/19/2022 06:12:00 PM  Sep 2022    05/28/2022
# 155781   A888385  Buttercup  09/29/2023 01:20:00 PM  Sep 2023    04/05/2023
# 155782   A889822     Kasche  09/29/2023 01:53:00 PM  Sep 2023    09/28/2021
# 155783   A889880  Charlotte  09/29/2023 01:40:00 PM  Sep 2023    09/29/2013
#
# ...

# %%
aa_csm = pd.read_csv('Austin_Animal_Center_Stray_Map.csv')
aa_csm
# Out:
#     Animal ID                                     Found Location  \
# 0     A878853  5408 WESTMINSTER DRIVE\nAUSTIN 78723\n(30.3066...
# 1     A879012  5005 BUFFALO PASS\nAUSTIN 78745\n(30.22331, -9...
# 2     A682044                                    JAKES HILL78660
# 3     A878939                       EMERALD FOREST\nAUSTIN 78745
# 4     A879033  7301 SPICEWOOD SPRING RD78759\n(30.40673, -97....
# ..        ...                                                ...
# 119   A878945  6209 VERA LN\nAUSTIN 78741\n(30.23839, -97.69567)
# 120   A879026                                       8718 FM78719
# 121   A879061  16211 CENTRAL COMMERENCE DR78660\n(30.45859, -...
# 122   A878906  5827 LEVANDER\nAUSTIN 78702\n(30.24746, -97.69...
# 123   A879011  11607 OLD LOCKHART RD78610\n(30.10557, -97.73671)
#
#                          At AAC Intake Date Type              Looks Like  \
# 0     Yes (come to the shelter)  04/18/2023  Dog            Pit Bull Mix
# ...

# %%
aa_co1 = aa_co[aa_co['Outcome Type'] == 'Euthanasia']
aa_co1
# Out:
#        Animal ID     Name                DateTime MonthYear Date of Birth  \
# 2        A821648      NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 19       A773792      NaN  06/05/2018 03:30:00 PM  Jun 2018    05/05/2018
# 24       A725795      NaN  05/03/2016 12:39:00 PM  May 2016    04/15/2016
# 28       A878380  A878380  04/15/2023 10:15:00 AM  Apr 2023    04/11/2021
# 34       A766700      NaN  02/15/2018 08:59:00 AM  Feb 2018    02/15/2017
# ...          ...      ...                     ...       ...           ...
# 155668   A859419      NaN  06/17/2022 10:23:00 AM  Jun 2022    05/20/2022
# 155670   A861610  A861610  07/19/2022 10:16:00 AM  Jul 2022    07/15/2020
# 155671   A859732      NaN  06/21/2022 10:23:00 AM  Jun 2022    02/17/2022
# 155672   A861869      NaN  07/22/2022 10:15:00 AM  Jul 2022    07/18/2020
# 155695   A887489    Ozzie  09/27/2023 04:17:00 PM  Sep 2023    12/22/2022
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# ...

# %% [markdown]
# # Here we were trying to help in mission 4 and 3. The idea was to take all animals which got to Euthansia and group them by the reasons Euthansia was made.

# %%
aa_co1['Outcome Subtype'].value_counts()
# Out:
# Outcome Subtype
# Rabies Risk            4439
# Suffering              3807
# Aggressive              595
# Medical                 340
# At Vet                  213
# Behavior                166
# Court/Investigation      61
# Underage                 37
# Name: count, dtype: int64

# %% [markdown]
# Here

# %%
aa_co1['Animal Type'].value_counts()
# Out:
# Animal Type
# Other        5444
# Cat          2319
# Dog          2028
# Bird          139
# Livestock       2
# Name: count, dtype: int64

# %% [markdown]
# # Here we tried to provide help with mission 2 and calculate does the shelter provide live outcomes for at least 95% of sheltered animals or no. So, everything except Died, Euthanasia, Disposal,  Missing, Stolen can be assessed as success

# %%
aa_co2=aa_co['Outcome Type'].value_counts()
aa_co2
# Out:
# Outcome Type
# Adoption           73304
# Transfer           44768
# Return to Owner    24363
# Euthanasia          9932
# Died                1466
# Rto-Adopt           1053
# Disposal             753
# Missing               83
# Relocate              27
# Stolen                 5
# Name: count, dtype: int64

# %%
aa_co2.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 10 entries, Adoption to Stolen
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 10 non-null     int64
# dtypes: int64(1)
# memory usage: 460.0+ bytes
